# %% [markdown]
# <a href="https://colab.research.google.com/github/HilmyMhiii/PCVK_Genap_2023/blob/main/Week9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %%
# DILASI CROSS 3X3 TANPA LIBRARY

# Input image
img_dilasi = cv2.imread('/content/drive/MyDrive/PCVK/morphology.png')
img_dilasi = cv2.cvtColor(img_dilasi, cv2.COLOR_BGR2GRAY)

# Membuat struktur element berbentuk square 3x3
se = np.ones((3,3))

def morph_dilate(img, kernel):
    rows = img.shape[0]
    cols = img.shape[1]
    dilate_img=np.zeros((rows,cols))

    newimg=np.zeros((img.shape[0]+2,img.shape[1]+2))
    newimg[1:-1,1:-1]=img
    for x in range(0,rows-(kernel.shape[0]-1)):
        for y in range(0,cols-kernel.shape[0]-1):
            dilate_img[x,y]=np.max(se * newimg[x:x+kernel.shape[0],y:y+kernel.shape[0]])

    return dilate_img

# Citra hasil dilasi
dilasi_img = morph_dilate(img_dilasi, se)

fig, axs = plt.subplots(1, 2, figsize=(9,5))

# Menampilkan citra awal
axs[0].set_title("Citra Awal")
axs[0].imshow(img_dilasi, cmap='gray')

# Menampilkan citra hasil dilasi
axs[1].set_title("Citra Hasil Dilasi")
axs[1].imshow(dilasi_img, cmap='gray')

# %%
# DILASI CROSS 3X3 DENGAN MENGGUNAKAN LIBRARY

# Input image
img_dilasi = cv2.imread('/content/drive/MyDrive/PCVK/morphology.png')

# Membuat struktur element berbentuk square 3x3
se = np.ones((3,3))

# Hasil dilasi menggunakan library opencv morphology
dilasi_img = cv2.morphologyEx(img_dilasi, cv2.MORPH_DILATE, se)

fig, axs = plt.subplots(1, 2, figsize=(9,5))
print(kernel)

# Menampilkan citra awal
axs[0].set_title("Citra Awal")
axs[0].imshow(dilasi_img)

# Menampilkan citra hasil dilasi
axs[1].set_title("Citra Hasil Dilasi")
axs[1].imshow(img_dilasi)
# Out:
# [[0 1 0]
#  [1 1 1]
#  [0 1 0]]

# %%
# EROSI SQUARE 5X5 TANPA LIBRARY

# Input image
img_erosi = cv2.imread('/content/drive/MyDrive/PCVK/j.png')
img_erosi = cv2.cvtColor(img_erosi, cv2.COLOR_BGR2GRAY)

# Membuat struktur element berbentuk square 5x5
se = np.ones((5,5))

def morph_erode(img, kernel):
    rows = img.shape[0]
    cols = img.shape[1]
    erode_img=np.zeros((rows,cols))

    newimg=np.zeros((img.shape[0]+2,img.shape[1]+2))
    newimg[1:-1,1:-1]=img
    for x in range(0,rows-(kernel.shape[0]-1)):
        for y in range(0,cols-(kernel.shape[0]-1)):
            erode_img[x,y]=np.min(se * newimg[x:x+kernel.shape[0],y:y+kernel.shape[0]])
    return erode_img

# Citra hasil erosi
erosi_img = morph_erode(img_erosi, se)

fig, axs = plt.subplots(1, 2, figsize=(9,5))

# Menampilkan citra awal
axs[0].set_title("Citra Awal")
axs[0].imshow(img_erosi, cmap='gray')

# Menampilkan citra hasil erosi
axs[1].set_title("Citra Hasil Erosi")
axs[1].imshow(erosi_img, cmap='gray')

# %%
# EROSI SQUARE 5X5 DENGAN MENGGUNAKAN LIBRARY

# Input image
img_erosi = cv2.imread('/content/drive/MyDrive/PCVK/j.png')

# Membuat structured element berbentuk square 5x5
se = np.ones((5,5))

# Hasil erosi menggunakan library opencv morphology
erosi_img = cv2.morphologyEx(img_erosi, cv2.MORPH_ERODE, se)

fig, axs = plt.subplots(1, 2, figsize=(9,5))

# Menampilkan citra awal
axs[0].set_title("Citra Awal")
axs[0].imshow(img_erosi)

# Menampilkan citra hasil erosi
axs[1].set_title("Citra Hasil Erosi")
axs[1].imshow(erosi_img)
